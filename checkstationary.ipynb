# %% [markdown]
# __Import Required Libraries__

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import lightgbm as lgb
import xgboost as xgb
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ****Loading test and train dataset****

# %%
# Load the dataset
data = pd.read_csv('DS_ML Coding Challenge Dataset (1).xlsx - Training Dataset.csv') 
data_test = pd.read_csv('DS_ML Coding Challenge Dataset (1).xlsx - Test Dataset.csv')

# %% [markdown]
# **EDA Starts Here**

# %%
sns.set_style("whitegrid")  # Add a grid
plt.figure(figsize=(10, 6))
sns.lineplot(x=data['Month of Sourcing'], y=data['Sourcing Cost'])
plt.xlabel('Month of Sourcing')
plt.ylabel('Sourcing Cost')
plt.grid(True)  # This line might not be necessary but can be used as a backup
plt.show()
# Out:
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Ploting CountPlot**

# %%
# Set the style of seaborn
sns.set(style="whitegrid")

# Create subplots for each categorical variable
fig, axes = plt.subplots(3, 2, figsize=(15, 15))

# Iterate over each categorical variable and plot count plots
categorical_columns = ['ProductType', 'Manufacturer', 'Area Code', 'Sourcing Channel', 'Product Size', 'Product Type']
for col, ax in zip(categorical_columns, axes.flatten()):
    sns.countplot(x=col, data=data, ax=ax)
    ax.set_title(f'Count of samples by {col}')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# **From here barplot start  ploting  all columns with sourcing cost**

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='ProductType', y='Sourcing Cost', data=data)
plt.title('Mean Sourcing Cost by ProductType')
plt.show()
# Out:
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Manufacturer', y='Sourcing Cost', data=data)
plt.title('Mean Sourcing Cost by Manufacturer')
plt.show()
# Out:
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(20, 10))
sns.barplot(x='Area Code', y='Sourcing Cost', data=data)
plt.title('Mean Sourcing Cost by Area Code')
plt.show()
# Out:
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Sourcing Channel', y='Sourcing Cost', data=data)
plt.title('Mean Sourcing Cost by Sourcing Channel')
plt.show()
# Out:
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Sourcing Channel', y='Sourcing Cost', data=data)
plt.title('Mean Sourcing Cost by Sourcing Channel')
plt.show()
# Out:
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Product Type', y='Sourcing Cost', data=data)
plt.title('Mean Sourcing Cost by Product Type')
plt.show()
# Out:
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# **Checking the negative value in sourcing cost columns in training dataset if any present they consider as outlier**

# %%
# Filter negative values
negative_data = data[data['Sourcing Cost'] < 0]

# Create box plot for negative values
plt.figure(figsize=(8, 6))
sns.boxplot(x='Sourcing Cost', data=negative_data, color='salmon')
plt.title('Box Plot of Negative Sourcing Cost')
plt.xlabel('Sourcing Cost')
plt.ylabel('Sourcing Cost')
plt.show()
# Out:
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# **Total number negative value present in sourcing cost is 184**

# %%
negative_values = data[data['Sourcing Cost'] < 0]
print("Number of negative values in 'Sourcing Cost':", len(negative_values))
# Out:
# Number of negative values in 'Sourcing Cost': 184

# %% [markdown]
# **Checking the negative value in sourcing cost columns in testing dataset if any present they consider as outlier**

# %%
# Check for negative values
negative_values = data_test[data_test['Sourcing Cost'] < 0]
print("Number of negative values in 'Sourcing Cost':", len(negative_values))
# Out:
# Number of negative values in 'Sourcing Cost': 0

# %%
# Select rows where 'Sourcing Cost' is negative
negative_rows = data[data['Sourcing Cost'] < 0]

# Create a new DataFrame with these rows
negative_df = pd.DataFrame(negative_rows)

# %%
negative_df
# Out:
#        ProductType Manufacturer Area Code Sourcing Channel Product Size  \
# 6858          NTM2           X1       A19           DIRECT        Large
# 14919         NTM2           X1       A19           DIRECT        Large
# 17275         NTM2           X1       A19           DIRECT        Large
# 20801         NTM2           X1       A19           DIRECT        Large
# 21030         NTM2           X1       A19           DIRECT        Large
# ...            ...          ...       ...              ...          ...
# 542765        NTM2           X2       A44           RETAIL        Large
# 545608        NTM2           X1       A16           DIRECT        Small
# 545860        NTM2           X1       A16           DIRECT        Small
# 547744        NTM2           X1       A16           DIRECT        Small
# 549339        NTM2           X1       A16           DIRECT        Small
#
#        Product Type Month of Sourcing  Sourcing Cost
# 6858         Powder            Apr-21         -57.60
# 14919        Powder            Apr-21         -57.60
# 17275        Powder            Apr-21         -57.60
# 20801        Powder            Apr-21         -57.60
# 21030        Powder            Apr-21         -57.60
# ...             ...               ...            ...
# 542765       Powder            May-21          -0.58
# 545608       Powder            May-21         -10.92
# 545860       Powder            May-21         -10.92
# 547744       Powder            May-21         -10.92
# 549339       Powder            May-21         -10.92
#
# [184 rows x 8 columns]

# %% [markdown]
# **Removing the negative value(which is outlier) from training dataset**

# %%
# Remove rows with negative 'Sourcing Cost' from the training dataset permanently
data= data[data['Sourcing Cost'] >0]

# Confirm the removal
print("Number of rows in training data after removing negative values:", len(data))
# Out:
# Number of rows in training data after removing negative values: 534400

# %% [markdown]
# **Preprocessing function for training data**

# %%
def preprocess_data(data):
    # One-hot encoding for categorical variables
    categorical_columns = ['ProductType', 'Manufacturer', 'Area Code', 'Sourcing Channel', 'Product Type']
    data = pd.get_dummies(data, columns=categorical_columns)

    # Label encoding for 'Product Size' column
    label_encoder = LabelEncoder()
    data['Product Size'] = label_encoder.fit_transform(data['Product Size'])
    # data['Month of Sourcing'] = label_encoder.fit_transform(data['Month of Sourcing'])

    # Datetime conversion
    data['Month of Sourcing'] = pd.to_datetime(data['Month of Sourcing'], format='%b-%y')
    
    data['Sourcing Cost'] = data['Sourcing Cost'].astype(int)
    # Convert datetime to integer representation
    data['Month of Sourcing'] = data['Month of Sourcing'].apply(lambda x: x.timestamp())
    # Convert to integer
    data['Month of Sourcing'] = data['Month of Sourcing'].astype(int)

    return data

# %% [markdown]
# **This preprocessing function used in time of test**

# %%
def preprocess_data_test(data):
    # One-hot encoding for categorical variables
    categorical_columns = ['ProductType', 'Manufacturer', 'Area Code', 'Sourcing Channel', 'Product Type']
    data = pd.get_dummies(data, columns=categorical_columns)

    # Label encoding for 'Product Size' column
    label_encoder = LabelEncoder()
    data['Product Size'] = label_encoder.fit_transform(data['Product Size'])
    # data['Month of Sourcing'] = label_encoder.fit_transform(data['Month of Sourcing'])

    # Datetime conversion
    data['Month of Sourcing'] = pd.to_datetime(data['Month of Sourcing'], format='%b-%y')
    
    # data['Sourcing Cost'] = data['Sourcing Cost'].astype(int)
    # Convert datetime to integer representation
    data['Month of Sourcing'] = data['Month of Sourcing'].apply(lambda x: x.timestamp())
    # Convert to integer
    data['Month of Sourcing'] = data['Month of Sourcing'].astype(int)

    return data

# %%
train_data = preprocess_data(data)

# %%
train_data
# Out:
#         Product Size  Month of Sourcing  Sourcing Cost  ProductType_NTM1  \
# 0                  1         1619827200             10             False
# 1                  1         1601510400            134             False
# 2                  1         1606780800             12             False
# 3                  2         1612137600            107             False
# 4                  1         1604188800            197             False
# ...              ...                ...            ...               ...
# 550171             1         1593561600            136             False
# 550172             1         1601510400             72             False
# 550173             2         1614556800            147             False
# 550174             2         1612137600            150             False
# 550175             2         1604188800            139              True
#
#         ProductType_NTM2  ProductType_NTM3  Manufacturer_X1  Manufacturer_X2  \
# 0                  False              True             True            False
# 1                   True             False             True            False
# 2                  False              True            False             True
# 3                  False              True             True            False
# 4                   True             False             True            False
# ...                  ...               ...              ...              ...
# 550171              True             False             True            False
# 550172             False              True             True            False
# 550173              True             False             True            False
# 550174              True             False             True            False
# 550175             False             False             True            False
#
#         Manufacturer_X3  Area Code_A1  ...  Area Code_A6  Area Code_A7  \
# 0                 False         False  ...         False         False
# 1                 False         False  ...         False         False
# 2                 False         False  ...         False         False
# 3                 False         False  ...         False         False
# 4                 False         False  ...         False         False
# ...                 ...           ...  ...           ...           ...
# 550171            False         False  ...         False         False
# 550172            False         False  ...         False         False
# 550173            False         False  ...         False         False
# 550174            False         False  ...         False          True
# 550175            False         False  ...         False         False
#
#         Area Code_A8  Area Code_A9  Sourcing Channel_DIRECT  \
# 0              False         False                    False
# 1              False          True                     True
# 2              False         False                     True
# 3              False         False                    False
# 4              False         False                     True
# ...              ...           ...                      ...
# 550171         False         False                     True
# 550172         False         False                     True
# 550173         False         False                     True
# 550174         False         False                     True
# 550175         False         False                     True
#
#         Sourcing Channel_ECOM  Sourcing Channel_RETAIL  \
# 0                       False                    False
# 1                       False                    False
# 2                       False                    False
# 3                       False                    False
# 4                       False                    False
# ...                       ...                      ...
# 550171                  False                    False
# 550172                  False                    False
# 550173                  False                    False
# 550174                  False                    False
# 550175                  False                    False
#
#         Sourcing Channel_WHOLESALE  Product Type_Liquid  Product Type_Powder
# 0                             True                False                 True
# 1                            False                False                 True
# 2                            False                False                 True
# 3                             True                False                 True
# 4                            False                 True                False
# ...                            ...                  ...                  ...
# 550171                       False                False                 True
# 550172                       False                 True                False
# 550173                       False                False                 True
# 550174                       False                False                 True
# 550175                       False                False                 True
#
# [534400 rows x 60 columns]

# %%
test_data = preprocess_data(data_test)

# %%
test_data
# Out:
#     Product Size  Month of Sourcing  Sourcing Cost  ProductType_NTM1  \
# 0              2         1622505600            103              True
# 1              1         1622505600            155              True
# 2              1         1622505600            143              True
# 3              1         1622505600            139              True
# 4              1         1622505600            169              True
# ..           ...                ...            ...               ...
# 91             2         1622505600             89             False
# 92             1         1622505600            114             False
# 93             2         1622505600            111             False
# 94             1         1622505600             32             False
# 95             1         1622505600             40             False
#
#     ProductType_NTM2  ProductType_NTM3  Manufacturer_X1  Manufacturer_X2  \
# 0              False             False             True            False
# 1              False             False             True            False
# 2              False             False             True            False
# 3              False             False             True            False
# 4              False             False             True            False
# ..               ...               ...              ...              ...
# 91             False              True             True            False
# 92             False              True             True            False
# 93             False              True             True            False
# 94             False              True            False             True
# 95             False              True            False            False
#
#     Manufacturer_X3  Area Code_A1  ...  Area Code_A6  Area Code_A7  \
# 0             False          True  ...         False         False
# 1             False         False  ...         False         False
# 2             False         False  ...         False         False
# 3             False         False  ...         False         False
# 4             False         False  ...         False         False
# ..              ...           ...  ...           ...           ...
# 91            False         False  ...         False         False
# 92            False         False  ...         False         False
# 93            False         False  ...         False         False
# 94            False         False  ...         False         False
# 95             True         False  ...         False         False
#
#     Area Code_A8  Area Code_A9  Sourcing Channel_DIRECT  \
# 0          False         False                     True
# 1          False         False                     True
# 2          False         False                    False
# 3          False         False                     True
# 4          False         False                     True
# ..           ...           ...                      ...
# 91         False         False                     True
# 92          True         False                     True
# 93          True         False                     True
# 94         False         False                     True
# 95         False         False                    False
#
#     Sourcing Channel_ECOM  Sourcing Channel_RETAIL  \
# 0                   False                    False
# 1                   False                    False
# 2                    True                    False
# 3                   False                    False
# 4                   False                    False
# ..                    ...                      ...
# 91                  False                    False
# 92                  False                    False
# 93                  False                    False
# 94                  False                    False
# 95                  False                     True
#
#     Sourcing Channel_WHOLESALE  Product Type_Liquid  Product Type_Powder
# 0                        False                False                 True
# 1                        False                False                 True
# 2                        False                False                 True
# 3                        False                False                 True
# 4                        False                False                 True
# ..                         ...                  ...                  ...
# 91                       False                 True                False
# 92                       False                False                 True
# 93                       False                False                 True
# 94                       False                False                 True
# 95                       False                False                 True
#
# [96 rows x 60 columns]

# %%
print(test_data.dtypes)
# Out:
# Product Size                  int32
# Month of Sourcing             int32
# Sourcing Cost                 int32
# ProductType_NTM1               bool
# ProductType_NTM2               bool
# ProductType_NTM3               bool
# Manufacturer_X1                bool
# Manufacturer_X2                bool
# Manufacturer_X3                bool
# Area Code_A1                   bool
# Area Code_A10                  bool
# Area Code_A11                  bool
# Area Code_A12                  bool
# Area Code_A13                  bool
# Area Code_A14                  bool
# Area Code_A15                  bool
# Area Code_A16                  bool
# Area Code_A17                  bool
# Area Code_A18                  bool
# Area Code_A19                  bool
# Area Code_A2                   bool
# Area Code_A20                  bool
# Area Code_A21                  bool
# Area Code_A22                  bool
# Area Code_A23                  bool
# Area Code_A24                  bool
# Area Code_A25                  bool
# Area Code_A26                  bool
# Area Code_A28                  bool
# Area Code_A29                  bool
# Area Code_A3                   bool
# Area Code_A30                  bool
# Area Code_A31                  bool
# Area Code_A32                  bool
# Area Code_A33                  bool
# Area Code_A34                  bool
# Area Code_A35                  bool
# Area Code_A36                  bool
# Area Code_A37                  bool
# Area Code_A38                  bool
# Area Code_A39                  bool
# Area Code_A4                   bool
# Area Code_A40                  bool
# Area Code_A41                  bool
# Area Code_A42                  bool
# Area Code_A43                  bool
# Area Code_A44                  bool
# Area Code_A45                  bool
# Area Code_A46                  bool
# Area Code_A5                   bool
# Area Code_A6                   bool
# Area Code_A7                   bool
# Area Code_A8                   bool
# Area Code_A9                   bool
# Sourcing Channel_DIRECT        bool
# Sourcing Channel_ECOM          bool
# Sourcing Channel_RETAIL        bool
# Sourcing Channel_WHOLESALE     bool
# Product Type_Liquid            bool
# Product Type_Powder            bool
# dtype: object

# %% [markdown]
# **Spliting the trainig data in X which contain all the columns except sourcing cost and y contains only sourcing cost**

# %%
X = train_data.drop(['Sourcing Cost'], axis=1)
y = train_data['Sourcing Cost']

# %% [markdown]
# **Here we are split the training data in which we have test_size=0.000001 which means training dataset used for pure training**

# %%
X_train, _, y_train, _ = train_test_split(X, y, test_size=0.000001, random_state=42)

# %% [markdown]
# **Spliting the testing data in X which contain all the columns except sourcing cost and y contains only sourcing cost**

# %%
x = test_data.drop(['Sourcing Cost'], axis=1)
Y= test_data['Sourcing Cost']

# %% [markdown]
# **Here we are split the testing data in which we have test_size=0.98 which means testing dataset used for pure testing**

# %%
_, x_test, _, Y_test = train_test_split(x, Y, test_size=0.98, random_state=42)

# %% [markdown]
# **Here using RandomForestRegressor**

# %%
model = RandomForestRegressor(n_estimators=200, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %% [markdown]
# **Here we are doing prediction and finding MSE value**

# %%
y_pred = model.predict(x_test)
mse = mean_squared_error(Y_test, y_pred)
print("Mean Squared Error on Validation Set:", mse)
# Out:
# Mean Squared Error on Validation Set: 1091.1290712995265

# %% [markdown]
# **Here we are  finding MAE value**

# %%
mae = mean_absolute_error(Y_test,y_pred)
print("Mean absolute Error on Validation Set:", mae)
# Out:
# Mean absolute Error on Validation Set: 16.595008409987116

# %% [markdown]
# **Here using LightGBM Model**

# %%
# Convert data to LightGBM Dataset format
train_data = lgb.Dataset(X_train, label=y_train)
val_data = lgb.Dataset(x_test, label= Y_test, reference=train_data)

# Define LightGBM parameters
params = {
    'objective': 'regression',
    'metric': 'rmse',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'early_stopping_rounds': 10,  # Specify early stopping rounds here
    'verbose': -1
}

# Train the LightGBM model
num_rounds = 200
model01 = lgb.train(params, train_data, num_rounds, valid_sets=[val_data])

# Predict on validation set
y_pred01 = model01.predict(x_test, num_iteration=model01.best_iteration)

# Calculate Root Mean Squared Error (RMSE)
rmse = mean_squared_error(Y_test, y_pred01) ** 0.5
print("Root Mean Squared Error on Validation Set:", rmse)
# Out:
# Root Mean Squared Error on Validation Set: 31.18690549190822

# %% [markdown]
# **Here we are finding MSE value**

# %%
mse = mean_squared_error(Y_test, y_pred01)
print("Mean Squared Error on Validation Set:", mse)
# Out:
# Mean Squared Error on Validation Set: 972.6230741612152

# %% [markdown]
# **Here we are finding MAE**

# %%
mae = mean_absolute_error(Y_test,y_pred01)
print("Mean absolute Error on Validation Set:", mae)
# Out:
# Mean absolute Error on Validation Set: 18.44842195386791

# %% [markdown]
# **Here using XGBoost Model**

# %%
# Convert data to XGBoost DMatrix format
dtrain = xgb.DMatrix(X_train, label=y_train)
dval = xgb.DMatrix(x_test, label=Y_test)

# Define XGBoost parameters
params = {
    'objective': 'reg:squarederror',  # for regression tasks
    'eval_metric': 'rmse',             # Root Mean Squared Error
    'eta': 0.05,                       # learning rate
    'max_depth': 6,                    # maximum depth of the tree
    'min_child_weight': 1,             # minimum sum of instance weight (hessian) needed in a child
    'early_stopping_rounds': 10,       # specify the number of rounds to wait for early stopping
    'verbose': False                   # verbosity
}

# Train the XGBoost model
num_rounds = 200
model02 = xgb.train(params, dtrain, num_rounds, evals=[(dtrain, 'train'), (dval, 'validation')], early_stopping_rounds=params['early_stopping_rounds'])

# Predict on validation set
y_pred02 = model02.predict(dval)

# Calculate Root Mean Squared Error (RMSE)
rmse = mean_squared_error(Y_test, y_pred02) ** 0.5
print("Root Mean Squared Error on Validation Set:", rmse)
# Out:
# C:\Users\Medhansh\miniconda3\envs\tensorflow\lib\site-packages\xgboost\core.py:160: UserWarning: [09:48:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "early_stopping_rounds", "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	train-rmse:103.11446	validation-rmse:50.62173
# [1]	train-rmse:102.13380	validation-rmse:48.90016
# [2]	train-rmse:101.23404	validation-rmse:47.35294
# [3]	train-rmse:100.41254	validation-rmse:45.89410
# [4]	train-rmse:99.69287	validation-rmse:44.66978
# [5]	train-rmse:99.03720	validation-rmse:43.55870
# [6]	train-rmse:98.41430	validation-rmse:42.39484
# [7]	train-rmse:97.86722	validation-rmse:41.43875
# [8]	train-rmse:97.33406	validation-rmse:40.41037
# [9]	train-rmse:96.87823	validation-rmse:39.49850
# [10]	train-rmse:96.46966	validation-rmse:38.88424
# [11]	train-rmse:96.06389	validation-rmse:38.05278
# [12]	train-rmse:95.69840	validation-rmse:37.50893
# [13]	train-rmse:95.38457	validation-rmse:36.93583
# [14]	train-rmse:95.05026	validation-rmse:36.39927
# [15]	train-rmse:94.78680	validation-rmse:35.92546
# [16]	train-rmse:94.50330	validation-rmse:35.48285
# [17]	train-rmse:94.24969	validation-rmse:35.09054
# [18]	train-rmse:94.02082	validation-rmse:34.64129
# [19]	train-rmse:93.66525	validation-rmse:34.42076
# [20]	train-rmse:93.47049	validation-rmse:34.08725
# [21]	train-rmse:93.31286	validation-rmse:33.89272
# [22]	train-rmse:93.15747	validation-rmse:33.67037
# [23]	train-rmse:92.73996	validation-rmse:33.45478
# [24]	train-rmse:92.62288	validation-rmse:33.38125
# [25]	train-rmse:92.49666	validation-rmse:33.17585
# [26]	train-rmse:92.11800	validation-rmse:32.97357
# [27]	train-rmse:92.02685	validation-rmse:33.00844
# [28]	train-rmse:91.92730	validation-rmse:32.87960
# [29]	train-rmse:91.60082	validation-rmse:32.77097
# [30]	train-rmse:91.49814	validation-rmse:32.79795
# [31]	train-rmse:91.42667	validation-rmse:32.70231
# [32]	train-rmse:91.21696	validation-rmse:32.68163
# [33]	train-rmse:90.97887	validation-rmse:32.61699
# [34]	train-rmse:90.89722	validation-rmse:32.80358
# [35]	train-rmse:90.84479	validation-rmse:32.60030
# [36]	train-rmse:90.78857	validation-rmse:32.49603
# [37]	train-rmse:90.57984	validation-rmse:32.46130
# [38]	train-rmse:90.51233	validation-rmse:32.53496
# [39]	train-rmse:90.47533	validation-rmse:32.49325
# [40]	train-rmse:90.43271	validation-rmse:32.28472
# [41]	train-rmse:90.39924	validation-rmse:32.34185
# [42]	train-rmse:90.14306	validation-rmse:32.31804
# [43]	train-rmse:89.91913	validation-rmse:32.30569
# [44]	train-rmse:89.73073	validation-rmse:32.52808
# [45]	train-rmse:89.67814	validation-rmse:32.37223
# [46]	train-rmse:89.50587	validation-rmse:32.49472
# [47]	train-rmse:89.37785	validation-rmse:32.40286
# [48]	train-rmse:89.34234	validation-rmse:32.38319
# [49]	train-rmse:89.25744	validation-rmse:32.49027
# [50]	train-rmse:89.20708	validation-rmse:32.28351
# [51]	train-rmse:89.11241	validation-rmse:32.34042
# [52]	train-rmse:89.06864	validation-rmse:32.25501
# [53]	train-rmse:88.98254	validation-rmse:32.30706
# [54]	train-rmse:88.94456	validation-rmse:32.19190
# [55]	train-rmse:88.86613	validation-rmse:32.24471
# [56]	train-rmse:88.84530	validation-rmse:32.22240
# [57]	train-rmse:88.81184	validation-rmse:32.02790
# [58]	train-rmse:88.66143	validation-rmse:32.08525
# [59]	train-rmse:88.65276	validation-rmse:32.11946
# [60]	train-rmse:88.53446	validation-rmse:32.21062
# [61]	train-rmse:88.50471	validation-rmse:32.06340
# [62]	train-rmse:88.37782	validation-rmse:32.12699
# [63]	train-rmse:88.36976	validation-rmse:32.27643
# [64]	train-rmse:88.34478	validation-rmse:32.14917
# [65]	train-rmse:88.24086	validation-rmse:32.17761
# [66]	train-rmse:88.21646	validation-rmse:32.19706
# [67]	train-rmse:88.11193	validation-rmse:32.23327
# Root Mean Squared Error on Validation Set: 32.23326814460094

# %% [markdown]
# **Here we are finding MSE**

# %%
mse = mean_squared_error(Y_test, y_pred02)
print("Mean Squared Error on Validation Set:", mse)
# Out:
# Mean Squared Error on Validation Set: 1038.983575281746

# %% [markdown]
# **Here using DecisionTreerRegressor Model**

# %%
# Train the Decision Tree model
model_dt = DecisionTreeRegressor()
model_dt.fit(X_train, y_train)

# Predict on validation set
y_pred_dt = model_dt.predict(x_test)

# Calculate Root Mean Squared Error (RMSE)
rmse_dt = mean_squared_error(Y_test, y_pred_dt) ** 0.5
print("Root Mean Squared Error on Validation Set (Decision Tree):", rmse_dt)
# Out:
# Root Mean Squared Error on Validation Set (Decision Tree): 33.07416182300121

# %% [markdown]
# **Here we are finding MSE**

# %%
mse = mean_squared_error(Y_test,y_pred_dt)
print("Mean Squared Error on Validation Set:", mse)
# Out:
# Mean Squared Error on Validation Set: 1093.9001802940707

# %% [markdown]
# **Here we are storing the sourcing cost column from test dataset which is used in time prediction**

# %%
test_source= test_data['Sourcing Cost']

# %% [markdown]
# **Here we are removing the sourcing cost column from test dataset because in time of testing we didnt require sourcing cost column as we now that we are predictin sourcing cost**

# %%
test_data.drop(['Sourcing Cost'], axis=1,inplace=True)

# %% [markdown]
# **Making prediction**

# %%
# Load the test dataset

# Make predictions on the test data (assuming model is already trained)
test_predictions = model01.predict(test_data)

# Print test predictions
print("Test Predictions:")
print(test_predictions)
# Out:
# Test Predictions:
# [108.94261491 145.64527092 145.64527092 144.60975743 162.30907055
#  157.29494171  71.63367073  72.89665053 144.60975743 144.60975743
#  141.67182727 141.25623597 103.82707529 144.60975743 144.60975743
#  144.60975743 144.60975743 144.60975743 141.67182727 144.60975743
#  144.60975743 144.60975743 144.60975743  34.18539579  78.86198968
#   43.51183089  55.34885479  40.49365207  32.15968461 208.47767057
#  184.42565119 159.03451067  40.49365207  31.88579861  58.79616611
#  142.94819726 145.64527092 144.60975743 142.28335556 191.11641277
#   72.33698404  96.73770689 162.30907055 162.30907055 133.86940272
#   50.29530187 197.49513295 197.49513295 107.67199505  83.30980706
#   72.3051463  142.28335556 131.32495456 121.46574799 172.07361058
#  146.75744396 144.43104209 201.47689712 163.36845686 144.60975743
#  142.28335556 144.60975743 142.28335556 144.60975743 144.60975743
#  144.60975743 142.28335556 144.60975743 142.28335556 144.60975743
#  144.60975743  93.65217386  68.27887429  67.67988801  55.49973774
#   54.49339591  36.84830145 123.20391477 103.61854998  48.17465277
#   58.16642254  49.36861529 147.58792368 108.46507333  84.81053319
#  123.76964732  79.10890895  36.81103502  36.20192549  79.99423227
#   67.31096081  75.23908246 115.99269132  91.76551015  52.82468529
#   54.49339591]

# %% [markdown]
# **Calculating the loss using MSE  Evaluation**

# %%
# Assuming original values are stored in 'original_values'
original_values = test_source  # Replace [...] with your original values

# Calculate Mean Squared Error (MSE)
mse = np.mean((test_predictions - original_values) ** 2)
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 962.7233206261244

# %% [markdown]
# **Here we can see that Sourcing cost value corresponding all columns**

# %%
# Read the CSV file into a DataFrame
testing = pd.read_csv('DS_ML Coding Challenge Dataset (1).xlsx - Test Dataset.csv')
testing.drop(['Sourcing Cost'], axis=1, inplace=True)

# Preprocess the testing data
testing_preprocessed = preprocess_data_test(testing)

# Make predictions on the preprocessed testing data
test_predictions = model01.predict(testing_preprocessed)

# Print input and corresponding prediction values
print("Input and Corresponding Prediction Values:")
for index, row in testing.iterrows():
    print("Input:", row.to_dict())
    print("Prediction:", test_predictions[index])
    print()  # Add a blank line for better readability

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(test_source, test_predictions)
print("Mean Squared Error (MSE):", mse)
# Out:
# Input and Corresponding Prediction Values:
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A1', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 108.94261491496485
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A10', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 145.6452709199658
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A10', 'Sourcing Channel': 'ECOM', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 145.6452709199658
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A11', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A2', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 162.3090705492215
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A2', 'Sourcing Channel': 'ECOM', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 157.2949417058007
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A28', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 71.63367073391434
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A29', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 72.89665052647013
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A3', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A3', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A3', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 141.67182727342896
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A33', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 141.25623597062153
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A34', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 103.82707528918165
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A4', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A6', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A7', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A7', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A7', 'Sourcing Channel': 'ECOM', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A7', 'Sourcing Channel': 'ECOM', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 141.67182727342896
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A8', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A8', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A9', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X1', 'Area Code': 'A9', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X2', 'Area Code': 'A12', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 34.1853957941352
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X2', 'Area Code': 'A21', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 78.86198967847194
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X2', 'Area Code': 'A30', 'Sourcing Channel': 'RETAIL', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 43.51183089051911
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X2', 'Area Code': 'A31', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 55.348854787249785
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X2', 'Area Code': 'A39', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 40.4936520706456
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X2', 'Area Code': 'A40', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 32.15968461174412
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X2', 'Area Code': 'A42', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 208.47767057093853
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X2', 'Area Code': 'A42', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 184.42565119289958
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X2', 'Area Code': 'A43', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 159.03451066505517
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X2', 'Area Code': 'A44', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 40.4936520706456
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X2', 'Area Code': 'A45', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 31.88579860707383
#
# Input: {'ProductType': 'NTM1', 'Manufacturer': 'X2', 'Area Code': 'A46', 'Sourcing Channel': 'RETAIL', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 58.796166111902075
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A10', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 142.94819725890966
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A10', 'Sourcing Channel': 'ECOM', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 145.6452709199658
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A11', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A11', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 142.28335555797509
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A16', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 191.11641277346905
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A17', 'Sourcing Channel': 'ECOM', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 72.33698404034128
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A19', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 96.73770689259455
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A2', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 162.3090705492215
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A2', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 162.3090705492215
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A23', 'Sourcing Channel': 'RETAIL', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 133.86940271587423
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A26', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 50.29530187161991
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A28', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 197.49513294894166
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A28', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 197.49513294894166
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A28', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 107.67199504553838
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A29', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 83.30980705613952
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A29', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 72.3051463032609
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A3', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 142.28335555797509
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A32', 'Sourcing Channel': 'RETAIL', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 131.32495455665327
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A32', 'Sourcing Channel': 'RETAIL', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 121.46574798673238
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A36', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 172.07361058373496
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A37', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 146.75744396398616
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A37', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.43104209362195
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A38', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 201.47689712248925
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A38', 'Sourcing Channel': 'RETAIL', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 163.36845686462746
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A4', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A41', 'Sourcing Channel': 'WHOLESALE', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 142.28335555797509
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A5', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A5', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 142.28335555797509
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A6', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A6', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A7', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A7', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 142.28335555797509
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A7', 'Sourcing Channel': 'ECOM', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A7', 'Sourcing Channel': 'ECOM', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 142.28335555797509
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A8', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X1', 'Area Code': 'A9', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 144.6097574283393
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X2', 'Area Code': 'A21', 'Sourcing Channel': 'RETAIL', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 93.65217385712103
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X2', 'Area Code': 'A25', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 68.27887429300166
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X2', 'Area Code': 'A31', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 67.67988800889171
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X2', 'Area Code': 'A32', 'Sourcing Channel': 'RETAIL', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 55.49973773664257
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X2', 'Area Code': 'A44', 'Sourcing Channel': 'RETAIL', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 54.493395914632295
#
# Input: {'ProductType': 'NTM2', 'Manufacturer': 'X2', 'Area Code': 'A45', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 36.84830145219207
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A10', 'Sourcing Channel': 'ECOM', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 123.20391477276895
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A11', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 103.61854998402815
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A13', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 48.17465277317325
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A14', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 58.16642254145847
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A15', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 49.36861529081173
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A18', 'Sourcing Channel': 'RETAIL', 'Product Size': 'Large', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 147.58792367725292
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A18', 'Sourcing Channel': 'WHOLESALE', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 108.46507333290013
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A24', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 84.81053318865567
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A25', 'Sourcing Channel': 'RETAIL', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 123.76964731879929
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A25', 'Sourcing Channel': 'RETAIL', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 79.10890895041925
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A28', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 36.81103501533343
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A28', 'Sourcing Channel': 'WHOLESALE', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 36.20192549244398
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A35', 'Sourcing Channel': 'DIRECT', 'Product Size': 'ExtraLarge', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 79.99423227158643
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A35', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 67.31096081287933
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A44', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Liquid', 'Month of Sourcing': 'Jun-21'}
# Prediction: 75.23908245522364
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A8', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 115.99269132118972
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X1', 'Area Code': 'A8', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Small', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 91.76551015004796
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X2', 'Area Code': 'A20', 'Sourcing Channel': 'DIRECT', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 52.82468529228752
#
# Input: {'ProductType': 'NTM3', 'Manufacturer': 'X3', 'Area Code': 'A22', 'Sourcing Channel': 'RETAIL', 'Product Size': 'Large', 'Product Type': 'Powder', 'Month of Sourcing': 'Jun-21'}
# Prediction: 54.493395914632295
#
# Mean Squared Error (MSE): 962.7233206261244

# %% [markdown]
# **We choosen ligthgbm model for prediction because we saw that its MSE value is less as compared to another three model**
